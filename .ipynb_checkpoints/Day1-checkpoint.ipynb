# %%
a = 30
b = 25 
c = 20

if a > b > c:
    print(a)
# Out:
# 30

# %%
if a > b and  b > c:
    print(a)
# Out:
# 30

# %%
if a > b or c > b:
    print("True")
# Out:
# True

# %%
if 7:
    print("Hii")
# Out:
# Hii

# %%
if -7:
    print("False")
# Out:
# False

# %%
if 0:
    print("true")

# %%
a = 10
a += 10
a
# Out:
# 20

# %%
# Bitwise
''' 5 -- 101
    3 -- 011
       -----------
             001'''
# Out:
# ' 5 -- 101\n    3 -- 011\n       -----------\n             001'

# %%
5 and 3
# Out:
# 3

# %%
7 | 9 # Bitwise OR
# Out:
# 15

# %%
7 & 9 # Bitwise AND
# Out:
# 1

# %%
11^2 # Bitwise XOR
# Out:
# 9

# %%
~7
# Step1:- change the sign of given number
# Step2:- Subtract 1 from it
# Out:
# -8

# %%
~11
# Out:
# -12

# %%
~-11
# Out:
# 10

# %%
# Left Shift
# a<<b
'''Step1:- First calculate the binary of a
   Step2:- Make it a near byte number
   Step3:- Remove B Bites from the left side
   step4:- add Bnumber of zeroes right side
   step5:- Convert into decimal'''
# Out:
# 320

# %%
13<<5
# Out:
# 416

# %%
## Right Shift
13>>2
# Out:
# 3

# %%
# WAP to add two numbers but do not use plus sign
a = 5
b = 5
add = a+b

# %%
add
# Out:
# 10

# %%
print(sum([5, 7]))   # Output: 12
# Out:
# 12

# %%
# Wap to subtract to numbers but without using - sign
import operator
print(operator.sub(5, -2))
# Out:
# 7

# %%
## Wap to subtract to numbers but without using - sign(using ~)

a = 10
b = 5
c = a + (~b+1)
c
# Out:
# 5

# %%
# WAP to even odd number but do not use %
a = 6

if a & +1 == 1:
    print("Odd")
else:
    print("Even")
# Out:
# Even
